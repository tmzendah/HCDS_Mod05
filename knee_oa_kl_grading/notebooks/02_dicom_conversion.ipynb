# %% [markdown]
# # 02 — DICOM to JPEG Conversion
#
# Converts raw MRKR DICOM files to JPEG using `scripts/convert_dicom_to_jpeg.py`.
#
# See `config/config.yaml` for output paths.

# %%
import subprocess
subprocess.run([
    'python', 'scripts/convert_dicom_to_jpeg.py',
    '--input_dir', 'data/raw/mrkr_dicoms',
    '--output_dir', 'data/processed',
    '--size', '512'
])
