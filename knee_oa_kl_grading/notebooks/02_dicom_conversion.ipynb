# %% [markdown]
# # 02 — DICOM to PNG Conversion
#
# Converts raw MRKR DICOM files to PNG using `scripts/convert_dicom_to_png.py`.
#
# See `config/config.yaml` for output paths.

# %%
import subprocess
subprocess.run([
    'python', 'scripts/convert_dicom_to_png.py',
    '--input_dir', 'data/raw/mrkr/dicoms',
    '--output_dir', 'data/processed',
    '--size', '512'
])
