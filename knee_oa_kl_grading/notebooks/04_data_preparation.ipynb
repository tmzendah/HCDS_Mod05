# %% [markdown]
# # 04 — Data Preparation
#
# Applies the filter cascade and builds the train/val/test split.
#
# **Filter cascade:**
# 1. Frontal views only (AP/PA)
# 2. Exclude post-arthroplasty knees
# 3. Valid KL grades 0–4
# 4. Bilateral expansion (one row per knee)
# 5. Stratified random sample: 2,000 images per grade
#
# **Split:** patient-level stratified 70 / 15 / 15

# %%
import subprocess
subprocess.run([
    'python', 'scripts/prepare_data.py',
    '--config', 'config/config.yaml'
])
